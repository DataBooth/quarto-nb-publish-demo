# %% [raw]
# ---
# title: "Example Notebook with Quarto Front Matter"
# author: "Your Name"
# date: "2024-10-10"
# format:
#   html:
#     toc: true
#     code-fold: true
# jupyter: python3
# ---

# %% [markdown]
# ## Introduction
#
# This is an example Jupyter notebook that includes Quarto front matter. The front matter is included in a raw cell at the beginning of the notebook.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# 1. Hide code but show output:
#
# ```
# #| echo: false
# ```

# %%
#| echo: false

# Create a sample dataframe

df = pd.DataFrame({'x': range(1, 11), 'y': [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]})

# %% [markdown]
# 2. Show code but hide output:
#
# ```
# #| output: false
# ```

# %%
#| output: false

import numpy as np
random_numbers = np.random.rand(5)
print(random_numbers)
# Out:
# [0.38517852 0.41351152 0.1274455  0.76385906 0.50095235]

# %% [markdown]
# 3. Hide both code and output:
#
# ```
# #| include: false
# ```

# %%
#| include: false

plt.plot([1, 2, 3, 4])
plt.show()

# %% [markdown]
# 4. Show code with line numbers:
#
# ```
# #| echo: true
# #| code-line-numbers: true
# ```

# %%
#| echo: true
#| code-line-numbers: true

def fibonacci(n):
    if n <= 1:
        return n
    else:
        return fibonacci(n-1) + fibonacci(n-2)

print(fibonacci(10))
# Out:
# 55

# %% [markdown]
# 5. Fold code (collapsible):
#
# ```
# #| code-fold: true
# ```

# %%
#| code-fold: true

import seaborn as sns
import matplotlib.pyplot as plt

tips = sns.load_dataset("tips")
sns.scatterplot(data=tips, x="total_bill", y="tip")
plt.show()

# %% [markdown]
# 6. Include warnings in output:
#
# ```
# #| warning: true
# ```

# %%
#| warning: true

import warnings
warnings.warn("This is a warning message")
# Out:
# /var/folders/pf/662q3gzd6413np78gpd4p9hr0000gn/T/ipykernel_38315/2745731313.py:4: UserWarning: This is a warning message
#   warnings.warn("This is a warning message")

# %% [markdown]
# 7. Set figure dimensions:
#
# ```
# #| fig-width: 8
# #| fig-height: 6
# ```

# %%
#| fig-width: 8
#| fig-height: 6

plt.plot([1, 2, 3, 4])
plt.title("Custom Size Plot")
plt.show()

# %%
# Create a simple plot

plt.figure(figsize=(10, 6))
plt.plot(df['x'], df['y'], marker='o')
plt.title('Sample Plot')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.grid(True)
plt.show()

# %%
df
# Out:
#     x    y
# 0   1    1
# 1   2    4
# 2   3    9
# 3   4   16
# 4   5   25
# 5   6   36
# 6   7   49
# 7   8   64
# 8   9   81
# 9  10  100

# %% [markdown]
# ## Conclusion
#
# This example demonstrates how to include Quarto front matter in a Jupyter notebook. When rendered with Quarto, this notebook will use the specified format options.
