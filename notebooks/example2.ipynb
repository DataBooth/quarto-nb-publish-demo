# %% [raw]
# ---
# title: "Second Example Notebook with Quarto Front Matter"
# author: "Michael Booth"
# date: "2024-10-09"
# format:
#   html:
#     toc: true
#     code-fold: true
# jupyter: python3
# ---

# %% [markdown]
# ## Introduction
#
# This is another example Jupyter notebook that includes Quarto front matter. The front matter is included in a raw cell at the beginning of the notebook.

# %%
#| output: false

import numpy as np
random_numbers = np.random.rand(5)
print(random_numbers)
# Out:
# [0.30336245 0.89500276 0.90744336 0.09300257 0.26600857]

# %%
#| include: true
#| fig-width: 5
#| fig-height: 3

import matplotlib.pyplot as plt

plt.plot(random_numbers)
plt.show()
